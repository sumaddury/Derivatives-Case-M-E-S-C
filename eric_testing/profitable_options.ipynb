# %%
import pandas as pd
import numpy as np
from datetime import datetime

pd.set_option("display.max_rows", None)

# %%
def parse_option_symbol(symbol):
    """
    example: SPX   240419C00800000
    """
    numbers = symbol.split(" ")[3]
    exp_date = datetime.strptime(numbers[:6], "%y%m%d")  # Convert to datetime object
    action = numbers[6]  # Extract the action ('C' or 'P')
    strike_price = float(numbers[7:]) / 1000  # Extract and convert the strike price
    return exp_date, action, strike_price

# %%
options = pd.read_csv(r"..\data\cleaned_options_data.csv")

# %%
options["datetime"] = pd.to_datetime(options["ts_recv"], format="%Y-%m-%dT%H:%M:%S.%fZ")
parsed_features = options["symbol"].apply(parse_option_symbol)
# Create new columns by unpacking the parsed features

(
    options["exp_date"],
    options["action"],
    options["strike_price"],
) = zip(*parsed_features)

options = options.rename(
    columns={
        "bid_px_00": "bidp",
        "ask_px_00": "askp",
        "bid_sz_00": "bid_sz",
        "ask_sz_00": "ask_sz",
    }
)

# %%
underlying = pd.read_csv(r"..\data\spx_minute_level_data_jan_mar_2024.csv")
underlying.columns = underlying.columns.str.lower()
underlying["date"] = pd.to_datetime(
    underlying["date"], format="%Y%m%d"
) + pd.to_timedelta(underlying["ms_of_day"], unit="ms")
underlying = underlying[["date", "price"]]
print(underlying.shape)
# Out:
# (23850, 2)

# %%
print(options.head(5))
# Out:
#                           ts_recv  instrument_id   bidp    askp  bid_sz  \
# 0  2024-01-02T14:30:02.402838204Z      587228771   27.0   27.70     174
# 1  2024-01-02T14:30:02.402844171Z      587211744    1.6    1.75     755
# 2  2024-01-02T14:30:02.402848382Z      587211728    4.1    4.40    1566
# 3  2024-01-02T14:30:02.410507796Z      587246038  121.1  123.70      15
# 4  2024-01-02T14:30:02.410507796Z      587237433   42.7   43.40      75
#
#    ask_sz                 symbol                      datetime   exp_date  \
# 0     155  SPX   240119P04700000 2024-01-02 14:30:02.402838204 2024-01-19
# 1    1981  SPX   240119P04300000 2024-01-02 14:30:02.402844171 2024-01-19
# 2    1125  SPX   240119P04500000 2024-01-02 14:30:02.402848382 2024-01-19
# 3      15  SPX   240216P04850000 2024-01-02 14:30:02.410507796 2024-02-16
# 4     120  SPX   240216P04650000 2024-01-02 14:30:02.410507796 2024-02-16
#
#   action  strike_price
# 0      P        4700.0
# 1      P        4300.0
# 2      P        4500.0
# 3      P        4850.0
# 4      P        4650.0

# %%
print(underlying.head(5))
# Out:
#                  date    price
# 0 2024-01-02 09:31:00  4742.96
# 1 2024-01-02 09:32:00  4743.24
# 2 2024-01-02 09:33:00  4744.84
# 3 2024-01-02 09:34:00  4744.11
# 4 2024-01-02 09:35:00  4743.49

# %%
def get_underlying(date):
    date = pd.Timestamp(date, tz="UTC").astimezone("US/Eastern").replace(tzinfo=None)

    index = underlying["date"].searchsorted(date)
    if index == 0:
        underlying_price = underlying["price"].iloc[0]
    elif index == len(underlying):
        underlying_price = underlying["price"].iloc[-1]
    else:
        before = underlying["date"].iloc[index - 1]
        after = underlying["date"].iloc[index]
        if abs(before - date) < abs(after - date):
            underlying_price = underlying["price"].iloc[index - 1]
        else:
            underlying_price = underlying["price"].iloc[index]
    # print(underlying.iloc[index])
    # print(underlying.iloc[index - 1])
    return underlying_price

# %%
curr = None
closest_call = closest_put = None
cc_val = cp_val = 10000

for i, option in options.iterrows():
    option_date = option["datetime"]
    underlying_price = get_underlying(option_date)
    option_date = option_date.date()

    # print(option)
    # print(underlying_price)
    # break

    if curr is None or curr != option_date:
        if curr != option_date:
            print(option_date)
            # TODO: process the closest call and put
            if closest_call is not None and closest_put is not None:
                exp_underlying = get_underlying(option["exp_date"])
                underlying_cost = closest_call["askp"] + closest_put["askp"]
                exp_price = get_underlying(option["exp_date"])
                call_profit = 100 * (underlying_price - closest_call["strike_price"])
                put_profit = 100 * (closest_put["strike_price"] - underlying_price)
                overall = max(call_profit, 0) + max(put_profit, 0) - underlying_cost
                print(
                    f"Date: {option_date}, Underlying: {underlying_price}, Closest Call: {closest_call}, Closest Put: {closest_put}, Overall: {overall}"
                )

        #     # Reset
        curr = option_date
        if option["action"] == "C":
            closest_call = option
            ccval = abs(option["strike_price"] - underlying_price)
            closest_put = None
            cpval = 10000
        else:
            closest_put = option
            cpval = abs(option["strike_price"] - underlying_price)
            closest_call = None
            ccval = 10000
    else:
        if option["action"] == "C":
            cccval = abs(option["strike_price"] - underlying_price)
            if cccval < ccval:
                closest_call = option
                ccval = cccval
        else:
            ccpval = abs(option["strike_price"] - underlying_price)
            if ccpval < cpval:
                closest_put = option
                cpval = ccpval
# Out:
# 2024-01-02
# 2024-01-03
# Date: 2024-01-03, Underlying: 0.0, Closest Call: datetime        2024-01-02 16:13:08.265789414
# bidp                                     50.8
# askp                                     51.5
# bid_sz                                    492
# ask_sz                                    348
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4740.0
# Name: 7291, dtype: object, Closest Put: datetime        2024-01-02 17:21:30.258022903
# bidp                                     38.0
# askp                                     38.5
# bid_sz                                    551
# ask_sz                                     75
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4750.0
# Name: 11351, dtype: object, Overall: 474910.0
# 2024-01-04
# Date: 2024-01-04, Underlying: 0.0, Closest Call: datetime        2024-01-03 17:02:26.979057821
# bidp                                     49.8
# askp                                     50.7
# bid_sz                                    480
# ask_sz                                    345
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4710.0
# Name: 32883, dtype: object, Closest Put: datetime        2024-01-03 20:00:14.448290860
# bidp                                     36.5
# askp                                     37.0
# bid_sz                                    330
# ask_sz                                    375
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4720.0
# Name: 39434, dtype: object, Overall: 471912.3
# 2024-01-05
# Date: 2024-01-05, Underlying: 0.0, Closest Call: datetime        2024-01-04 20:16:43.067891279
# bidp                                    166.0
# askp                                    167.1
# bid_sz                                    269
# ask_sz                                    151
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           4700.0
# Name: 56789, dtype: object, Closest Put: datetime        2024-01-04 20:47:52.988769492
# bidp                                     86.6
# askp                                     87.1
# bid_sz                                    407
# ask_sz                                    112
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4700.0
# Name: 58379, dtype: object, Overall: 469745.8
# 2024-01-08
# Date: 2024-01-08, Underlying: 0.0, Closest Call: datetime        2024-01-05 15:40:13.072369918
# bidp                                     87.1
# askp                                     88.2
# bid_sz                                    315
# ask_sz                                    135
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4715.0
# Name: 65155, dtype: object, Closest Put: datetime        2024-01-05 15:13:52.206373001
# bidp                                     34.2
# askp                                     34.7
# bid_sz                                    272
# ask_sz                                    150
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4715.0
# Name: 63918, dtype: object, Overall: 471377.1
# 2024-01-09
# Date: 2024-01-09, Underlying: 0.0, Closest Call: datetime        2024-01-08 20:33:41.195767478
# bidp                                    157.2
# askp                                    158.7
# bid_sz                                     28
# ask_sz                                     14
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           4755.0
# Name: 101352, dtype: object, Closest Put: datetime        2024-01-08 20:33:34.015005596
# bidp                                     30.2
# askp                                     30.7
# bid_sz                                    359
# ask_sz                                    543
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4755.0
# Name: 101341, dtype: object, Overall: 475310.6
# 2024-01-10
# Date: 2024-01-10, Underlying: 0.0, Closest Call: datetime        2024-01-09 16:25:02.714087540
# bidp                                     81.5
# askp                                     82.3
# bid_sz                                    544
# ask_sz                                    480
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4750.0
# Name: 113417, dtype: object, Closest Put: datetime        2024-01-09 16:24:30.347754536
# bidp                                     28.5
# askp                                     28.9
# bid_sz                                     75
# ask_sz                                    215
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4750.0
# Name: 113395, dtype: object, Overall: 474888.8
# 2024-01-11
# Date: 2024-01-11, Underlying: 0.0, Closest Call: datetime        2024-01-10 17:40:55.373499430
# bidp                                    112.1
# askp                                    112.7
# bid_sz                                     92
# ask_sz                                    126
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4770.0
# Name: 136880, dtype: object, Closest Put: datetime        2024-01-10 19:02:09.356590206
# bidp                                    167.1
# askp                                    168.1
# bid_sz                                     86
# ask_sz                                     65
# exp_date                  2024-09-20 00:00:00
# action                                      P
# strike_price                           4775.0
# Name: 139831, dtype: object, Overall: 477219.2
# 2024-01-12
# Date: 2024-01-12, Underlying: 0.0, Closest Call: datetime        2024-01-11 18:53:37.828045826
# bidp                                     74.2
# askp                                     74.9
# bid_sz                                     51
# ask_sz                                     90
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4770.0
# Name: 162423, dtype: object, Closest Put: datetime        2024-01-11 17:51:57.652182425
# bidp                                     24.1
# askp                                     24.9
# bid_sz                                    478
# ask_sz                                    325
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4760.0
# Name: 160467, dtype: object, Overall: 475900.2
# 2024-01-16
# Date: 2024-01-16, Underlying: 0.0, Closest Call: datetime        2024-01-12 19:30:37.920299299
# bidp                                     23.9
# askp                                     24.3
# bid_sz                                    203
# ask_sz                                    109
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4785.0
# Name: 189019, dtype: object, Closest Put: datetime        2024-01-12 19:49:52.108919105
# bidp                                     20.5
# askp                                     20.9
# bid_sz                                    236
# ask_sz                                    172
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4780.0
# Name: 189875, dtype: object, Overall: 477954.8
# 2024-01-17
# Date: 2024-01-17, Underlying: 0.0, Closest Call: datetime        2024-01-16 18:53:37.950156636
# bidp                                     20.8
# askp                                     21.2
# bid_sz                                    164
# ask_sz                                    267
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4755.0
# Name: 213896, dtype: object, Closest Put: datetime        2024-01-16 15:58:06.701459160
# bidp                                     18.1
# askp                                     18.5
# bid_sz                                    146
# ask_sz                                    200
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4780.0
# Name: 204875, dtype: object, Overall: 477960.3
# 2024-01-18
# Date: 2024-01-18, Underlying: 0.0, Closest Call: datetime        2024-01-17 16:32:21.245740762
# bidp                                     17.9
# askp                                     18.3
# bid_sz                                    227
# ask_sz                                    259
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4740.0
# Name: 236955, dtype: object, Closest Put: datetime        2024-01-17 15:21:06.905010867
# bidp                                     17.8
# askp                                     18.0
# bid_sz                                     19
# ask_sz                                     23
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4730.0
# Name: 232042, dtype: object, Overall: 472963.7
# 2024-01-19
# Date: 2024-01-19, Underlying: 0.0, Closest Call: datetime        2024-01-18 18:48:48.769388050
# bidp                                      9.0
# askp                                      9.4
# bid_sz                                     85
# ask_sz                                     98
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4755.0
# Name: 305879, dtype: object, Closest Put: datetime        2024-01-18 18:48:42.156253397
# bidp                                      9.7
# askp                                     10.0
# bid_sz                                    119
# ask_sz                                    160
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4755.0
# Name: 305875, dtype: object, Overall: 475480.6
# 2024-01-22
# Date: 2024-01-22, Underlying: 0.0, Closest Call: datetime        2024-01-19 16:44:30.217030868
# bidp                                     69.0
# askp                                     70.6
# bid_sz                                     53
# ask_sz                                     45
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4800.0
# Name: 343469, dtype: object, Closest Put: datetime        2024-01-19 16:45:11.985038588
# bidp                                     53.4
# askp                                     53.7
# bid_sz                                    195
# ask_sz                                    205
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4800.0
# Name: 343498, dtype: object, Overall: 479875.7
# 2024-01-23
# Date: 2024-01-23, Underlying: 0.0, Closest Call: datetime        2024-01-22 18:20:49.365127176
# bidp                                    205.2
# askp                                    206.7
# bid_sz                                    474
# ask_sz                                    254
# exp_date                  2024-06-21 00:00:00
# action                                      C
# strike_price                           4850.0
# Name: 388036, dtype: object, Closest Put: datetime        2024-01-22 15:04:34.087673241
# bidp                                     92.9
# askp                                     93.7
# bid_sz                                    153
# ask_sz                                    165
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           4860.0
# Name: 371541, dtype: object, Overall: 485699.6
# 2024-01-24
# Date: 2024-01-24, Underlying: 0.0, Closest Call: datetime        2024-01-23 14:43:15.196594640
# bidp                                     62.5
# askp                                     63.3
# bid_sz                                    363
# ask_sz                                    354
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4855.0
# Name: 398892, dtype: object, Closest Put: datetime        2024-01-23 17:48:43.251870799
# bidp                                     46.2
# askp                                     46.6
# bid_sz                                     45
# ask_sz                                    255
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4850.0
# Name: 408411, dtype: object, Overall: 484890.1
# 2024-01-25
# Date: 2024-01-25, Underlying: 0.0, Closest Call: datetime        2024-01-24 17:36:50.885435570
# bidp                                    200.6
# askp                                    202.1
# bid_sz                                    190
# ask_sz                                     58
# exp_date                  2024-06-21 00:00:00
# action                                      C
# strike_price                           4900.0
# Name: 435034, dtype: object, Closest Put: datetime        2024-01-24 17:10:53.095542728
# bidp                                    213.0
# askp                                    215.4
# bid_sz                                    416
# ask_sz                                    370
# exp_date                  2025-02-21 00:00:00
# action                                      P
# strike_price                           4900.0
# Name: 433511, dtype: object, Overall: 489582.5
# 2024-01-26
# Date: 2024-01-26, Underlying: 0.0, Closest Call: datetime        2024-01-25 19:08:44.264058433
# bidp                                     95.9
# askp                                     96.7
# bid_sz                                     54
# ask_sz                                     53
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4870.0
# Name: 463191, dtype: object, Closest Put: datetime        2024-01-25 20:25:21.885275179
# bidp                                    119.6
# askp                                    120.4
# bid_sz                                    113
# ask_sz                                    107
# exp_date                  2024-06-21 00:00:00
# action                                      P
# strike_price                           4880.0
# Name: 466793, dtype: object, Overall: 487782.9
# 2024-01-29
# Date: 2024-01-29, Underlying: 0.0, Closest Call: datetime        2024-01-26 15:32:55.820149268
# bidp                                     93.8
# askp                                     94.6
# bid_sz                                    225
# ask_sz                                    338
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4900.0
# Name: 473355, dtype: object, Closest Put: datetime        2024-01-26 15:32:46.571118195
# bidp                                     46.1
# askp                                     46.6
# bid_sz                                    465
# ask_sz                                    211
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4900.0
# Name: 473352, dtype: object, Overall: 489858.8
# 2024-01-30
# Date: 2024-01-30, Underlying: 0.0, Closest Call: datetime        2024-01-29 18:27:49.799256209
# bidp                                     54.2
# askp                                     54.8
# bid_sz                                    292
# ask_sz                                    513
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4900.0
# Name: 499390, dtype: object, Closest Put: datetime        2024-01-29 18:26:27.064910280
# bidp                                     66.6
# askp                                     67.1
# bid_sz                                    420
# ask_sz                                    490
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4900.0
# Name: 499340, dtype: object, Overall: 489878.1
# 2024-01-31
# Date: 2024-01-31, Underlying: 0.0, Closest Call: datetime        2024-01-30 20:09:40.267536791
# bidp                                    133.8
# askp                                    135.5
# bid_sz                                     60
# ask_sz                                     45
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           4925.0
# Name: 529982, dtype: object, Closest Put: datetime        2024-01-30 17:46:22.814963700
# bidp                                     43.2
# askp                                     43.7
# bid_sz                                    289
# ask_sz                                    372
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4920.0
# Name: 521900, dtype: object, Overall: 491820.8
# 2024-02-01
# Date: 2024-02-01, Underlying: 0.0, Closest Call: datetime        2024-01-31 16:28:34.058056279
# bidp                                    136.1
# askp                                    137.0
# bid_sz                                     90
# ask_sz                                     76
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           4885.0
# Name: 541667, dtype: object, Closest Put: datetime        2024-01-31 19:21:47.430939047
# bidp                                     43.0
# askp                                     43.8
# bid_sz                                    173
# ask_sz                                    284
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4875.0
# Name: 547896, dtype: object, Overall: 487319.2
# 2024-02-02
# Date: 2024-02-02, Underlying: 0.0, Closest Call: datetime        2024-02-01 16:28:11.199507744
# bidp                                     92.0
# askp                                     92.7
# bid_sz                                    289
# ask_sz                                    407
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4860.0
# Name: 563178, dtype: object, Closest Put: datetime        2024-02-01 17:01:33.529466076
# bidp                                     90.3
# askp                                     90.9
# bid_sz                                    133
# ask_sz                                    120
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           4875.0
# Name: 564694, dtype: object, Overall: 487316.4
# 2024-02-05
# Date: 2024-02-05, Underlying: 0.0, Closest Call: datetime        2024-02-02 16:58:33.719078810
# bidp                                     45.6
# askp                                     46.1
# bid_sz                                    178
# ask_sz                                    358
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4950.0
# Name: 587401, dtype: object, Closest Put: datetime        2024-02-02 15:03:33.031477484
# bidp                                     39.8
# askp                                     40.4
# bid_sz                                    495
# ask_sz                                    414
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4920.0
# Name: 578415, dtype: object, Overall: 491913.5
# 2024-02-06
# Date: 2024-02-06, Underlying: 0.0, Closest Call: datetime        2024-02-05 19:55:49.191549412
# bidp                                     82.7
# askp                                     83.3
# bid_sz                                    346
# ask_sz                                    148
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4955.0
# Name: 623992, dtype: object, Closest Put: datetime        2024-02-05 17:56:25.842562013
# bidp                                     63.4
# askp                                     63.8
# bid_sz                                    417
# ask_sz                                    271
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4945.0
# Name: 619333, dtype: object, Overall: 494352.9
# 2024-02-07
# Date: 2024-02-07, Underlying: 0.0, Closest Call: datetime        2024-02-06 18:34:10.656293001
# bidp                                    158.3
# askp                                    159.2
# bid_sz                                     69
# ask_sz                                     49
# exp_date                  2024-05-17 00:00:00
# action                                      C
# strike_price                           4945.0
# Name: 638960, dtype: object, Closest Put: datetime        2024-02-06 14:51:33.985012395
# bidp                                     34.6
# askp                                     35.2
# bid_sz                                    150
# ask_sz                                    150
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4950.0
# Name: 630144, dtype: object, Overall: 494805.6
# 2024-02-08
# Date: 2024-02-08, Underlying: 0.0, Closest Call: datetime        2024-02-07 20:46:32.803350684
# bidp                                     34.2
# askp                                     34.7
# bid_sz                                    220
# ask_sz                                    403
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4995.0
# Name: 671333, dtype: object, Closest Put: datetime        2024-02-07 16:12:38.818627302
# bidp                                     59.2
# askp                                     59.7
# bid_sz                                    496
# ask_sz                                    372
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4990.0
# Name: 655330, dtype: object, Overall: 498905.6
# 2024-02-09
# Date: 2024-02-09, Underlying: 0.0, Closest Call: datetime        2024-02-08 15:01:46.040337207
# bidp                                     33.1
# askp                                     33.6
# bid_sz                                    272
# ask_sz                                    377
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4995.0
# Name: 677299, dtype: object, Closest Put: datetime        2024-02-08 17:47:41.750778878
# bidp                                     29.2
# askp                                     29.5
# bid_sz                                    180
# ask_sz                                      5
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4990.0
# Name: 689334, dtype: object, Overall: 498936.9
# 2024-02-12
# Date: 2024-02-12, Underlying: 0.0, Closest Call: datetime        2024-02-09 19:26:46.929987552
# bidp                                     27.9
# askp                                     28.3
# bid_sz                                    312
# ask_sz                                    105
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           5025.0
# Name: 719606, dtype: object, Closest Put: datetime        2024-02-09 20:14:38.801353156
# bidp                                     98.9
# askp                                     99.6
# bid_sz                                    223
# ask_sz                                     20
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5025.0
# Name: 725492, dtype: object, Overall: 502372.1
# 2024-02-13
# Date: 2024-02-13, Underlying: 0.0, Closest Call: datetime        2024-02-12 15:17:59.487221033
# bidp                                     26.2
# askp                                     26.6
# bid_sz                                    303
# ask_sz                                    157
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           5025.0
# Name: 736794, dtype: object, Closest Put: datetime        2024-02-12 20:22:13.548527030
# bidp                                     58.2
# askp                                     58.7
# bid_sz                                    534
# ask_sz                                    600
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5025.0
# Name: 756584, dtype: object, Overall: 502414.7
# 2024-02-14
# Date: 2024-02-14, Underlying: 0.0, Closest Call: datetime        2024-02-13 20:46:41.598377506
# bidp                                     81.0
# askp                                     81.7
# bid_sz                                    264
# ask_sz                                    166
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4940.0
# Name: 794368, dtype: object, Closest Put: datetime        2024-02-13 20:46:39.806522682
# bidp                                     21.7
# askp                                     22.1
# bid_sz                                     20
# ask_sz                                     19
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4940.0
# Name: 794366, dtype: object, Overall: 493896.2
# 2024-02-15
# Date: 2024-02-15, Underlying: 0.0, Closest Call: datetime        2024-02-14 15:09:40.759476734
# bidp                                    120.3
# askp                                    122.0
# bid_sz                                     57
# ask_sz                                     30
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           4980.0
# Name: 802010, dtype: object, Closest Put: datetime        2024-02-14 15:10:05.205159468
# bidp                                     17.7
# askp                                     18.1
# bid_sz                                    106
# ask_sz                                     94
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4980.0
# Name: 802037, dtype: object, Overall: 497859.9
# 2024-02-16
# Date: 2024-02-16, Underlying: 0.0, Closest Call: datetime        2024-02-15 17:00:38.093885518
# bidp                                     12.1
# askp                                     12.5
# bid_sz                                    287
# ask_sz                                    288
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           5010.0
# Name: 852870, dtype: object, Closest Put: datetime        2024-02-15 14:39:37.379563790
# bidp                                     12.9
# askp                                     13.3
# bid_sz                                    254
# ask_sz                                     66
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           5010.0
# Name: 831458, dtype: object, Overall: 500974.2
# 2024-02-20
# Date: 2024-02-20, Underlying: 0.0, Closest Call: datetime        2024-02-16 15:18:04.733319944
# bidp                                     71.4
# askp                                     71.7
# bid_sz                                    247
# ask_sz                                     44
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5015.0
# Name: 890979, dtype: object, Closest Put: datetime        2024-02-16 15:17:51.020763796
# bidp                                    101.1
# askp                                    102.0
# bid_sz                                    172
# ask_sz                                    207
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5015.0
# Name: 890978, dtype: object, Overall: 501326.3
# 2024-02-21
# Date: 2024-02-21, Underlying: 0.0, Closest Call: datetime        2024-02-20 15:07:09.673965653
# bidp                                     71.6
# askp                                     72.2
# bid_sz                                     45
# ask_sz                                    272
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4975.0
# Name: 912701, dtype: object, Closest Put: datetime        2024-02-20 17:18:13.030521549
# bidp                                     57.8
# askp                                     58.3
# bid_sz                                    438
# ask_sz                                    210
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4960.0
# Name: 923864, dtype: object, Overall: 495869.5
# 2024-02-22
# Date: 2024-02-22, Underlying: 0.0, Closest Call: datetime        2024-02-21 20:32:35.493347199
# bidp                                     69.6
# askp                                     70.2
# bid_sz                                     45
# ask_sz                                     45
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4960.0
# Name: 946488, dtype: object, Closest Put: datetime        2024-02-21 20:48:42.612216241
# bidp                                     81.4
# askp                                     82.0
# bid_sz                                     30
# ask_sz                                     66
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           4970.0
# Name: 947449, dtype: object, Overall: 496847.8
# 2024-02-23
# Date: 2024-02-23, Underlying: 0.0, Closest Call: datetime        2024-02-22 18:33:53.360547504
# bidp                                     63.2
# askp                                     63.7
# bid_sz                                    222
# ask_sz                                    210
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5080.0
# Name: 971439, dtype: object, Closest Put: datetime        2024-02-22 17:08:18.094315832
# bidp                                     50.0
# askp                                     50.4
# bid_sz                                    279
# ask_sz                                    318
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5065.0
# Name: 963084, dtype: object, Overall: 506385.9
# 2024-02-26
# Date: 2024-02-26, Underlying: 0.0, Closest Call: datetime        2024-02-23 16:56:17.500795666
# bidp                                     59.7
# askp                                     60.4
# bid_sz                                    390
# ask_sz                                    441
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5095.0
# Name: 995983, dtype: object, Closest Put: datetime        2024-02-23 20:53:01.920336543
# bidp                                     47.1
# askp                                     47.7
# bid_sz                                    458
# ask_sz                                    423
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5095.0
# Name: 1007123, dtype: object, Overall: 509391.9
# 2024-02-27
# Date: 2024-02-27, Underlying: 0.0, Closest Call: datetime        2024-02-26 18:26:38.165892090
# bidp                                     56.4
# askp                                     57.2
# bid_sz                                    498
# ask_sz                                    216
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5075.0
# Name: 1021454, dtype: object, Closest Put: datetime        2024-02-26 18:26:38.165897204
# bidp                                     44.9
# askp                                     45.4
# bid_sz                                    272
# ask_sz                                    179
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5075.0
# Name: 1021455, dtype: object, Overall: 507397.4
# 2024-02-28
# Date: 2024-02-28, Underlying: 0.0, Closest Call: datetime        2024-02-27 17:59:01.500603880
# bidp                                     52.8
# askp                                     53.4
# bid_sz                                    309
# ask_sz                                    221
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5060.0
# Name: 1039605, dtype: object, Closest Put: datetime        2024-02-27 14:31:10.258811336
# bidp                                     44.0
# askp                                     44.6
# bid_sz                                     60
# ask_sz                                    346
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5075.0
# Name: 1030277, dtype: object, Overall: 507402.0
# 2024-02-29
# Date: 2024-02-29, Underlying: 0.0, Closest Call: datetime        2024-02-28 18:35:22.792948275
# bidp                                    102.9
# askp                                    104.1
# bid_sz                                    151
# ask_sz                                    246
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5075.0
# Name: 1058850, dtype: object, Closest Put: datetime        2024-02-28 20:09:14.628572699
# bidp                                     70.1
# askp                                     70.7
# bid_sz                                    292
# ask_sz                                    476
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5065.0
# Name: 1062073, dtype: object, Overall: 506325.2
# 2024-03-01
# Date: 2024-03-01, Underlying: 0.0, Closest Call: datetime        2024-02-29 16:38:19.751504578
# bidp                                     48.1
# askp                                     48.7
# bid_sz                                    111
# ask_sz                                     45
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5075.0
# Name: 1072627, dtype: object, Closest Put: datetime        2024-02-29 16:38:19.751504578
# bidp                                     42.0
# askp                                     42.6
# bid_sz                                     75
# ask_sz                                    166
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5075.0
# Name: 1072626, dtype: object, Overall: 507408.7
# 2024-03-04
# Date: 2024-03-04, Underlying: 0.0, Closest Call: datetime        2024-03-01 15:27:08.810302255
# bidp                                     47.0
# askp                                     47.4
# bid_sz                                    214
# ask_sz                                    209
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5110.0
# Name: 1086711, dtype: object, Closest Put: datetime        2024-03-01 15:27:10.216062831
# bidp                                     38.6
# askp                                     39.2
# bid_sz                                    412
# ask_sz                                    300
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5110.0
# Name: 1086713, dtype: object, Overall: 510913.4
# 2024-03-05
# Date: 2024-03-05, Underlying: 0.0, Closest Call: datetime        2024-03-04 14:35:03.416797327
# bidp                                     98.6
# askp                                    102.5
# bid_sz                                     61
# ask_sz                                     90
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5130.0
# Name: 1107323, dtype: object, Closest Put: datetime        2024-03-04 14:35:03.416802701
# bidp                                     67.6
# askp                                     68.4
# bid_sz                                     56
# ask_sz                                     56
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5130.0
# Name: 1107324, dtype: object, Overall: 512829.1
# 2024-03-06
# Date: 2024-03-06, Underlying: 0.0, Closest Call: datetime        2024-03-05 15:39:32.862840673
# bidp                                     45.3
# askp                                     45.9
# bid_sz                                    287
# ask_sz                                    385
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5085.0
# Name: 1136266, dtype: object, Closest Put: datetime        2024-03-05 14:31:17.630177543
# bidp                                     37.3
# askp                                     37.8
# bid_sz                                    202
# ask_sz                                    256
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5110.0
# Name: 1130512, dtype: object, Overall: 510916.3
# 2024-03-07
# Date: 2024-03-07, Underlying: 0.0, Closest Call: datetime        2024-03-06 17:12:19.069711023
# bidp                                     43.8
# askp                                     44.3
# bid_sz                                    361
# ask_sz                                    321
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5125.0
# Name: 1168268, dtype: object, Closest Put: datetime        2024-03-06 17:39:24.578765228
# bidp                                    112.8
# askp                                    113.3
# bid_sz                                     43
# ask_sz                                     90
# exp_date                  2024-06-21 00:00:00
# action                                      P
# strike_price                           5125.0
# Name: 1169157, dtype: object, Overall: 512342.4
# 2024-03-08
# Date: 2024-03-08, Underlying: 0.0, Closest Call: datetime        2024-03-07 16:10:14.855455070
# bidp                                    276.7
# askp                                    278.6
# bid_sz                                     22
# ask_sz                                     36
# exp_date                  2024-09-20 00:00:00
# action                                      C
# strike_price                           5150.0
# Name: 1186365, dtype: object, Closest Put: datetime        2024-03-07 16:10:14.855452401
# bidp                                    113.3
# askp                                    113.8
# bid_sz                                    252
# ask_sz                                     97
# exp_date                  2024-06-21 00:00:00
# action                                      P
# strike_price                           5150.0
# Name: 1186364, dtype: object, Overall: 514607.6
# 2024-03-11
# Date: 2024-03-11, Underlying: 0.0, Closest Call: datetime        2024-03-08 15:35:41.431244842
# bidp                                     36.7
# askp                                     37.2
# bid_sz                                    247
# ask_sz                                     28
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5180.0
# Name: 1221912, dtype: object, Closest Put: datetime        2024-03-08 16:48:49.803097410
# bidp                                     35.6
# askp                                     36.1
# bid_sz                                     38
# ask_sz                                    239
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5150.0
# Name: 1227176, dtype: object, Overall: 514926.7
# 2024-03-12
# Date: 2024-03-12, Underlying: 0.0, Closest Call: datetime        2024-03-11 14:19:47.519116995
# bidp                                     36.6
# askp                                     37.1
# bid_sz                                    137
# ask_sz                                    122
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5100.0
# Name: 1248129, dtype: object, Closest Put: datetime        2024-03-11 17:31:51.515919416
# bidp                                     71.5
# askp                                     72.1
# bid_sz                                     91
# ask_sz                                     90
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5120.0
# Name: 1259023, dtype: object, Overall: 511890.8
# 2024-03-13
# Date: 2024-03-13, Underlying: 0.0, Closest Call: datetime        2024-03-12 13:52:48.480401268
# bidp                                     94.8
# askp                                     95.6
# bid_sz                                     30
# ask_sz                                     30
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5125.0
# Name: 1270899, dtype: object, Closest Put: datetime        2024-03-12 13:48:44.151062722
# bidp                                     69.1
# askp                                     69.9
# bid_sz                                    339
# ask_sz                                    373
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5115.0
# Name: 1270461, dtype: object, Overall: 511334.5
# 2024-03-14
# Date: 2024-03-14, Underlying: 0.0, Closest Call: datetime        2024-03-13 18:04:36.772531695
# bidp                                     18.3
# askp                                     18.7
# bid_sz                                    119
# ask_sz                                    285
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5175.0
# Name: 1315376, dtype: object, Closest Put: datetime        2024-03-13 15:47:56.547630831
# bidp                                     16.6
# askp                                     16.9
# bid_sz                                    145
# ask_sz                                     85
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5165.0
# Name: 1307820, dtype: object, Overall: 516464.4
# 2024-03-15
# Date: 2024-03-15, Underlying: 0.0, Closest Call: datetime        2024-03-14 14:56:37.197843474
# bidp                                     15.2
# askp                                     15.6
# bid_sz                                    127
# ask_sz                                    185
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5150.0
# Name: 1344038, dtype: object, Closest Put: datetime        2024-03-14 14:57:03.280125191
# bidp                                     13.9
# askp                                     14.3
# bid_sz                                    120
# ask_sz                                    137
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5150.0
# Name: 1344083, dtype: object, Overall: 514970.1
# 2024-03-18
# Date: 2024-03-18, Underlying: 0.0, Closest Call: datetime        2024-03-15 14:15:46.126850410
# bidp                                     90.7
# askp                                     91.4
# bid_sz                                    181
# ask_sz                                     89
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5125.0
# Name: 1393736, dtype: object, Closest Put: datetime        2024-03-15 18:51:28.882608550
# bidp                                    125.3
# askp                                    126.0
# bid_sz                                     33
# ask_sz                                     83
# exp_date                  2024-07-19 00:00:00
# action                                      P
# strike_price                           5120.0
# Name: 1407182, dtype: object, Overall: 511782.6
# 2024-03-19
# Date: 2024-03-19, Underlying: 0.0, Closest Call: datetime        2024-03-18 19:24:38.251052469
# bidp                                    126.7
# askp                                    128.1
# bid_sz                                     45
# ask_sz                                     32
# exp_date                  2024-05-17 00:00:00
# action                                      C
# strike_price                           5160.0
# Name: 1430664, dtype: object, Closest Put: datetime        2024-03-18 14:28:33.974831921
# bidp                                    108.5
# askp                                    109.1
# bid_sz                                     79
# ask_sz                                    130
# exp_date                  2024-06-21 00:00:00
# action                                      P
# strike_price                           5175.0
# Name: 1419705, dtype: object, Overall: 517262.8
# 2024-03-20
# Date: 2024-03-20, Underlying: 0.0, Closest Call: datetime        2024-03-19 16:51:24.801850504
# bidp                                     84.6
# askp                                     85.4
# bid_sz                                    489
# ask_sz                                    459
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5170.0
# Name: 1442063, dtype: object, Closest Put: datetime        2024-03-19 18:13:55.283160034
# bidp                                     61.3
# askp                                     61.8
# bid_sz                                    398
# ask_sz                                    369
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5170.0
# Name: 1444873, dtype: object, Overall: 516852.8
# 2024-03-21
# Date: 2024-03-21, Underlying: 0.0, Closest Call: datetime        2024-03-20 17:59:00.115099454
# bidp                                    121.3
# askp                                    123.2
# bid_sz                                     15
# ask_sz                                     15
# exp_date                  2024-05-17 00:00:00
# action                                      C
# strike_price                           5175.0
# Name: 1460247, dtype: object, Closest Put: datetime        2024-03-20 17:59:00.115099454
# bidp                                     82.6
# askp                                     83.5
# bid_sz                                     79
# ask_sz                                     30
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5175.0
# Name: 1460246, dtype: object, Overall: 517293.3
# 2024-03-22
# Date: 2024-03-22, Underlying: 0.0, Closest Call: datetime        2024-03-21 13:34:47.731646809
# bidp                                     74.3
# askp                                     75.2
# bid_sz                                    576
# ask_sz                                    165
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5250.0
# Name: 1474111, dtype: object, Closest Put: datetime        2024-03-21 13:35:14.915583375
# bidp                                     78.3
# askp                                     79.1
# bid_sz                                    133
# ask_sz                                    345
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5250.0
# Name: 1474170, dtype: object, Overall: 524845.7
# 2024-03-25
# Date: 2024-03-25, Underlying: 0.0, Closest Call: datetime        2024-03-22 19:49:11.240664036
# bidp                                    113.6
# askp                                    115.4
# bid_sz                                     15
# ask_sz                                     15
# exp_date                  2024-05-17 00:00:00
# action                                      C
# strike_price                           5240.0
# Name: 1517415, dtype: object, Closest Put: datetime        2024-03-22 18:06:24.895848493
# bidp                                     76.2
# askp                                     76.8
# bid_sz                                    161
# ask_sz                                     75
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5245.0
# Name: 1513090, dtype: object, Overall: 524307.8
# 2024-03-26
# Date: 2024-03-26, Underlying: 0.0, Closest Call: datetime        2024-03-25 16:29:48.532532180
# bidp                                    439.3
# askp                                    442.8
# bid_sz                                     12
# ask_sz                                     24
# exp_date                  2025-03-21 00:00:00
# action                                      C
# strike_price                           5225.0
# Name: 1525948, dtype: object, Closest Put: datetime        2024-03-25 19:48:27.302681167
# bidp                                     49.7
# askp                                     50.1
# bid_sz                                    264
# ask_sz                                    157
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5225.0
# Name: 1532492, dtype: object, Overall: 522007.1
# 2024-03-27
# Date: 2024-03-27, Underlying: 0.0, Closest Call: datetime        2024-03-26 18:34:31.091689649
# bidp                                     64.4
# askp                                     65.2
# bid_sz                                    277
# ask_sz                                    210
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5230.0
# Name: 1545515, dtype: object, Closest Put: datetime        2024-03-26 18:34:31.091695007
# bidp                                     46.2
# askp                                     46.7
# bid_sz                                    416
# ask_sz                                    288
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5230.0
# Name: 1545516, dtype: object, Overall: 522888.1
# 2024-03-28
# Date: 2024-03-28, Underlying: 0.0, Closest Call: datetime        2024-03-27 19:21:30.504065955
# bidp                                     62.6
# askp                                     63.3
# bid_sz                                    183
# ask_sz                                    210
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5220.0
# Name: 1561155, dtype: object, Closest Put: datetime        2024-03-27 18:20:44.128434040
# bidp                                     45.2
# askp                                     45.5
# bid_sz                                     10
# ask_sz                                    224
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5225.0
# Name: 1559756, dtype: object, Overall: 522391.2

# %%
options["date"] = options["datetime"].dt.date
options.head(5)
# Out:
#                           ts_recv  instrument_id   bidp    askp  bid_sz  \
# 0  2024-01-02T14:30:02.402838204Z      587228771   27.0   27.70     174
# 1  2024-01-02T14:30:02.402844171Z      587211744    1.6    1.75     755
# 2  2024-01-02T14:30:02.402848382Z      587211728    4.1    4.40    1566
# 3  2024-01-02T14:30:02.410507796Z      587246038  121.1  123.70      15
# 4  2024-01-02T14:30:02.410507796Z      587237433   42.7   43.40      75
#
#    ask_sz                 symbol                      datetime   exp_date  \
# 0     155  SPX   240119P04700000 2024-01-02 14:30:02.402838204 2024-01-19
# 1    1981  SPX   240119P04300000 2024-01-02 14:30:02.402844171 2024-01-19
# 2    1125  SPX   240119P04500000 2024-01-02 14:30:02.402848382 2024-01-19
# 3      15  SPX   240216P04850000 2024-01-02 14:30:02.410507796 2024-02-16
# 4     120  SPX   240216P04650000 2024-01-02 14:30:02.410507796 2024-02-16
#
#   action  strike_price        date
# 0      P        4700.0  2024-01-02
# 1      P        4300.0  2024-01-02
# 2      P        4500.0  2024-01-02
# 3      P        4850.0  2024-01-02
# 4      P        4650.0  2024-01-02

# %%
curr = None
closest_call = closest_put = None
cc_val = cp_val = 10000

for i, option in options.iterrows():
    option_date = option["datetime"]
    underlying_price = get_underlying(option_date)
    option_date = option_date.date()

    # print(option)
    # print(underlying_price)
    # break

    if curr is None or curr != option_date:
        if curr != option_date:
            print(option_date)
            # TODO: process the closest call and put
            if closest_call is not None and closest_put is not None:
                exp_underlying = get_underlying(option["exp_date"])
                underlying_cost = closest_call["askp"] + closest_put["askp"]
                exp_price = get_underlying(option["exp_date"])
                call_profit = 100 * (underlying_price - closest_call["strike_price"])
                put_profit = 100 * (closest_put["strike_price"] - underlying_price)
                overall = max(call_profit, 0) + max(put_profit, 0) - underlying_cost
                print(
                    f"Date: {option_date}, Underlying: {underlying_price}, Closest Call: {closest_call}, Closest Put: {closest_put}, Overall: {overall}"
                )

        #     # Reset
        curr = option_date
        if option["action"] == "C":
            closest_call = option
            ccval = abs(option["strike_price"] - underlying_price)
            closest_put = None
            cpval = 10000
        else:
            closest_put = option
            cpval = abs(option["strike_price"] - underlying_price)
            closest_call = None
            ccval = 10000
    else:
        if option["action"] == "C":
            cccval = abs(option["strike_price"] - underlying_price)
            if cccval < ccval:
                closest_call = option
                ccval = cccval
        else:
            ccpval = abs(option["strike_price"] - underlying_price)
            if ccpval < cpval:
                closest_put = option
                cpval = ccpval
