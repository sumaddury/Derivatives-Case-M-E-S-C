# %%
import pandas as pd
import numpy as np
from datetime import datetime

pd.set_option("display.max_rows", None)

# %%
def parse_option_symbol(symbol):
    """
    example: SPX   240419C00800000
    """
    numbers = symbol.split(" ")[3]
    exp_date = datetime.strptime(numbers[:6], "%y%m%d")  # Convert to datetime object
    action = numbers[6]  # Extract the action ('C' or 'P')
    strike_price = float(numbers[7:]) / 1000  # Extract and convert the strike price
    return exp_date, action, strike_price

# %%
options = pd.read_csv(r"..\data\cleaned_options_data.csv")

# %%
options["datetime"] = pd.to_datetime(options["ts_recv"], format="%Y-%m-%dT%H:%M:%S.%fZ")
parsed_features = options["symbol"].apply(parse_option_symbol)
# Create new columns by unpacking the parsed features

(
    options["exp_date"],
    options["action"],
    options["strike_price"],
) = zip(*parsed_features)
options = options[
    [
        "datetime",
        "bid_px_00",
        "ask_px_00",
        "bid_sz_00",
        "ask_sz_00",
        "exp_date",
        "action",
        "strike_price",
    ]
]
options = options.rename(
    columns={
        "bid_px_00": "bidp",
        "ask_px_00": "askp",
        "bid_sz_00": "bid_sz",
        "ask_sz_00": "ask_sz",
    }
)

# %%
underlying = pd.read_csv(r"..\data\underlying_data_hour.csv")
underlying.columns = underlying.columns.str.lower()
underlying["date"] = pd.to_datetime(underlying["date"])
print(underlying.shape)
# Out:
# (427, 7)

# %%
print(options.head(5))
# Out:
#                        datetime   bidp    askp  bid_sz  ask_sz   exp_date  \
# 0 2024-01-02 14:30:02.402838204   27.0   27.70     174     155 2024-01-19
# 1 2024-01-02 14:30:02.402844171    1.6    1.75     755    1981 2024-01-19
# 2 2024-01-02 14:30:02.402848382    4.1    4.40    1566    1125 2024-01-19
# 3 2024-01-02 14:30:02.410507796  121.1  123.70      15      15 2024-02-16
# 4 2024-01-02 14:30:02.410507796   42.7   43.40      75     120 2024-02-16
#
#   action  strike_price
# 0      P        4700.0
# 1      P        4300.0
# 2      P        4500.0
# 3      P        4850.0
# 4      P        4650.0

# %%
print(underlying.head(5))
# Out:
#                         date         open         high          low  \
# 0  2024-01-02 09:30:00-05:00  4745.200195  4745.200195  4730.950195
# 1  2024-01-02 10:30:00-05:00  4736.100098  4742.439941  4731.169922
# 2  2024-01-02 11:30:00-05:00  4741.120117  4751.220215  4740.890137
# 3  2024-01-02 12:30:00-05:00  4747.549805  4754.330078  4740.919922
# 4  2024-01-02 13:30:00-05:00  4744.810059  4747.220215  4733.669922
#
#          close    adj close     volume
# 0  4736.259766  4736.259766          0
# 1  4741.120117  4741.120117  292380245
# 2  4747.549805  4747.549805  217999404
# 3  4744.799805  4744.799805  185937425
# 4  4737.020020  4737.020020  194942000

# %%
def get_underlying(date):
    date = pd.Timestamp(date, tz="UTC")
    index = underlying["date"].searchsorted(date)
    if index == 0:
        underlying_price = underlying["adj close"].iloc[0]
    elif index == len(underlying):
        underlying_price = underlying["adj close"].iloc[-1]
    else:
        before = underlying["date"].iloc[index - 1]
        after = underlying["date"].iloc[index]
        if abs(before - date) < abs(after - date):
            underlying_price = underlying["adj close"].iloc[index - 1]
        else:
            underlying_price = underlying["adj close"].iloc[index]
    # print(underlying.iloc[index])
    # print(underlying.iloc[index - 1])
    return underlying_price

# %%
curr = None
closest_call = closest_put = None
cc_val = cp_val = 10000

for i, option in options.iterrows():
    option_date = option["datetime"]
    underlying_price = get_underlying(option_date)
    option_date = option_date.date()

    # print(option)
    # print(underlying_price)
    # break

    if curr is None or curr != option_date:
        if curr != option_date:
            print(option_date)
            # TODO: process the closest call and put
            if closest_call is not None and closest_put is not None:
                exp_underlying = get_underlying(option["exp_date"])
                underlying_cost = closest_call["askp"] + closest_put["askp"]
                exp_price = get_underlying(option["exp_date"])
                call_profit = 100 * (underlying_price - closest_call["strike_price"])
                put_profit = 100 * (closest_put["strike_price"] - underlying_price)
                overall = max(call_profit, 0) + max(put_profit, 0) - underlying_cost
                print(
                    f"Date: {option_date}, Underlying: {underlying_price}, Closest Call: {closest_call}, Closest Put: {closest_put}, Overall: {overall}"
                )

        #     # Reset
        curr = option_date
        if option["action"] == "C":
            closest_call = option
            ccval = abs(option["strike_price"] - underlying_price)
            closest_put = None
            cpval = 10000
        else:
            closest_put = option
            cpval = abs(option["strike_price"] - underlying_price)
            closest_call = None
            ccval = 10000
    else:
        if option["action"] == "C":
            cccval = abs(option["strike_price"] - underlying_price)
            if cccval < ccval:
                closest_call = option
                ccval = cccval
        else:
            ccpval = abs(option["strike_price"] - underlying_price)
            if ccpval < cpval:
                closest_put = option
                cpval = ccpval
# Out:
# 2024-01-02
# 2024-01-03
# Date: 2024-01-03, Underlying: 4713.2099609375, Closest Call: datetime        2024-01-02 17:05:45.510331181
# bidp                                     53.2
# askp                                     54.0
# bid_sz                                    513
# ask_sz                                    369
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4745.0
# Name: 10468, dtype: object, Closest Put: datetime        2024-01-02 15:02:18.300953443
# bidp                                    139.6
# askp                                    140.6
# bid_sz                                     74
# ask_sz                                    142
# exp_date                  2024-06-21 00:00:00
# action                                      P
# strike_price                           4740.0
# Name: 2984, dtype: object, Overall: 2484.40390625
# 2024-01-04
# Date: 2024-01-04, Underlying: 4715.08984375, Closest Call: datetime        2024-01-03 15:25:06.382872652
# bidp                                     49.1
# askp                                     50.1
# bid_sz                                    277
# ask_sz                                    345
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4715.0
# Name: 27257, dtype: object, Closest Put: datetime        2024-01-03 15:00:12.817765554
# bidp                                     35.5
# askp                                     36.1
# bid_sz                                     75
# ask_sz                                     75
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4715.0
# Name: 25043, dtype: object, Overall: -77.215625
# 2024-01-05
# Date: 2024-01-05, Underlying: 4712.64013671875, Closest Call: datetime        2024-01-04 19:02:06.231708320
# bidp                                     97.6
# askp                                     98.4
# bid_sz                                    351
# ask_sz                                    338
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4700.0
# Name: 53798, dtype: object, Closest Put: datetime        2024-01-04 19:02:06.231708320
# bidp                                     62.8
# askp                                     63.2
# bid_sz                                    290
# ask_sz                                    222
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4700.0
# Name: 53797, dtype: object, Overall: 1102.413671875
# 2024-01-08
# Date: 2024-01-08, Underlying: 4717.25, Closest Call: datetime        2024-01-05 18:00:41.461678236
# bidp                                    157.4
# askp                                    158.3
# bid_sz                                    230
# ask_sz                                    152
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           4700.0
# Name: 71503, dtype: object, Closest Put: datetime        2024-01-05 17:00:29.427828437
# bidp                                     30.8
# askp                                     31.2
# bid_sz                                     75
# ask_sz                                    150
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4695.0
# Name: 68507, dtype: object, Overall: 1535.5
# 2024-01-09
# Date: 2024-01-09, Underlying: 4742.02978515625, Closest Call: datetime        2024-01-08 16:01:04.229409788
# bidp                                     37.0
# askp                                     37.4
# bid_sz                                     83
# ask_sz                                    321
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4725.0
# Name: 86813, dtype: object, Closest Put: datetime        2024-01-08 16:00:36.233373944
# bidp                                    162.0
# askp                                    163.2
# bid_sz                                     49
# ask_sz                                     13
# exp_date                  2024-08-16 00:00:00
# action                                      P
# strike_price                           4725.0
# Name: 86778, dtype: object, Overall: 1502.378515625
# 2024-01-10
# Date: 2024-01-10, Underlying: 4764.06982421875, Closest Call: datetime        2024-01-09 15:02:03.269439887
# bidp                                    293.6
# askp                                    296.0
# bid_sz                                     77
# ask_sz                                    121
# exp_date                  2024-09-20 00:00:00
# action                                      C
# strike_price                           4750.0
# Name: 108305, dtype: object, Closest Put: datetime        2024-01-09 15:00:00.338035812
# bidp                                     34.6
# askp                                     35.4
# bid_sz                                     75
# ask_sz                                     75
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4750.0
# Name: 108126, dtype: object, Overall: 1075.582421875
# 2024-01-11
# Date: 2024-01-11, Underlying: 4766.580078125, Closest Call: datetime        2024-01-10 15:31:16.127561513
# bidp                                     32.1
# askp                                     32.5
# bid_sz                                    285
# ask_sz                                    220
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4765.0
# Name: 130861, dtype: object, Closest Put: datetime        2024-01-10 15:44:03.492127792
# bidp                                     54.6
# askp                                     55.2
# bid_sz                                     56
# ask_sz                                     45
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4765.0
# Name: 131749, dtype: object, Overall: 70.3078125
# 2024-01-12
# Date: 2024-01-12, Underlying: 4780.85986328125, Closest Call: datetime        2024-01-11 20:13:51.996991281
# bidp                                     25.2
# askp                                     25.7
# bid_sz                                    212
# ask_sz                                    304
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4780.0
# Name: 165968, dtype: object, Closest Put: datetime        2024-01-11 20:04:50.584579032
# bidp                                     22.7
# askp                                     23.1
# bid_sz                                    291
# ask_sz                                    277
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4780.0
# Name: 165517, dtype: object, Overall: 37.186328125
# 2024-01-16
# Date: 2024-01-16, Underlying: 4776.72021484375, Closest Call: datetime        2024-01-12 16:01:09.524889235
# bidp                                     25.9
# askp                                     26.4
# bid_sz                                    343
# ask_sz                                    123
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4775.0
# Name: 178767, dtype: object, Closest Put: datetime        2024-01-12 16:01:09.524904265
# bidp                                     23.8
# askp                                     24.2
# bid_sz                                    100
# ask_sz                                    233
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4775.0
# Name: 178768, dtype: object, Overall: 121.421484375
# 2024-01-17
# Date: 2024-01-17, Underlying: 4734.41015625, Closest Call: datetime        2024-01-16 20:01:59.829584542
# bidp                                     16.7
# askp                                     17.0
# bid_sz                                    442
# ask_sz                                    117
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4765.0
# Name: 218507, dtype: object, Closest Put: datetime        2024-01-16 20:02:52.857117481
# bidp                                     20.0
# askp                                     20.7
# bid_sz                                     20
# ask_sz                                     20
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4765.0
# Name: 218640, dtype: object, Overall: 3021.284375
# 2024-01-18
# Date: 2024-01-18, Underlying: 4757.64990234375, Closest Call: datetime        2024-01-17 19:00:36.095294203
# bidp                                     16.3
# askp                                     16.7
# bid_sz                                    368
# ask_sz                                    178
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4725.0
# Name: 247016, dtype: object, Closest Put: datetime        2024-01-17 19:08:07.811921516
# bidp                                     16.4
# askp                                     16.7
# bid_sz                                    102
# ask_sz                                     26
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4725.0
# Name: 247394, dtype: object, Overall: 3231.590234375
# 2024-01-19
# Date: 2024-01-19, Underlying: 4795.7900390625, Closest Call: datetime        2024-01-18 19:00:00.043983657
# bidp                                      1.6
# askp                                      1.9
# bid_sz                                    141
# ask_sz                                     27
# exp_date                  2024-01-19 00:00:00
# action                                      C
# strike_price                           4780.0
# Name: 307397, dtype: object, Closest Put: datetime        2024-01-18 19:06:11.507024709
# bidp                                     22.4
# askp                                     23.4
# bid_sz                                     95
# ask_sz                                    160
# exp_date                  2024-01-19 00:00:00
# action                                      P
# strike_price                           4780.0
# Name: 308164, dtype: object, Overall: 1553.70390625
# 2024-01-22
# Date: 2024-01-22, Underlying: 4859.02978515625, Closest Call: datetime        2024-01-19 17:02:10.918028117
# bidp                                    160.8
# askp                                    162.5
# bid_sz                                    153
# ask_sz                                     77
# exp_date                  2024-05-17 00:00:00
# action                                      C
# strike_price                           4825.0
# Name: 344737, dtype: object, Closest Put: datetime        2024-01-19 17:28:25.273669036
# bidp                                     79.9
# askp                                     80.5
# bid_sz                                    272
# ask_sz                                    120
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4825.0
# Name: 346422, dtype: object, Overall: 3159.978515625
# 2024-01-23
# Date: 2024-01-23, Underlying: 4854.10986328125, Closest Call: datetime        2024-01-22 16:03:09.697546571
# bidp                                     98.2
# askp                                     99.0
# bid_sz                                    314
# ask_sz                                    387
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4855.0
# Name: 381431, dtype: object, Closest Put: datetime        2024-01-22 16:23:54.675164815
# bidp                                     71.3
# askp                                     71.8
# bid_sz                                    179
# ask_sz                                    368
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4855.0
# Name: 382818, dtype: object, Overall: -81.78632812500001
# 2024-01-24
# Date: 2024-01-24, Underlying: 4890.8701171875, Closest Call: datetime        2024-01-23 14:43:15.196594640
# bidp                                     62.5
# askp                                     63.3
# bid_sz                                    363
# ask_sz                                    354
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4855.0
# Name: 398892, dtype: object, Closest Put: datetime        2024-01-23 14:31:46.795288501
# bidp                                     47.6
# askp                                     48.1
# bid_sz                                    129
# ask_sz                                    117
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4855.0
# Name: 398357, dtype: object, Overall: 3475.61171875
# 2024-01-25
# Date: 2024-01-25, Underlying: 4895.8798828125, Closest Call: datetime        2024-01-24 15:16:03.846155820
# bidp                                     55.1
# askp                                     55.6
# bid_sz                                    193
# ask_sz                                    354
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4895.0
# Name: 424578, dtype: object, Closest Put: datetime        2024-01-24 15:37:17.963472010
# bidp                                     45.6
# askp                                     46.2
# bid_sz                                    588
# ask_sz                                    440
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4895.0
# Name: 426305, dtype: object, Overall: -13.811718750000011
# 2024-01-26
# Date: 2024-01-26, Underlying: 4897.39990234375, Closest Call: datetime        2024-01-25 20:21:05.065561184
# bidp                                     51.3
# askp                                     51.8
# bid_sz                                    348
# ask_sz                                    300
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4895.0
# Name: 466635, dtype: object, Closest Put: datetime        2024-01-25 20:14:01.543387701
# bidp                                     72.6
# askp                                     73.1
# bid_sz                                    347
# ask_sz                                     90
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4895.0
# Name: 466250, dtype: object, Overall: 115.09023437500001
# 2024-01-29
# Date: 2024-01-29, Underlying: 4892.31005859375, Closest Call: datetime        2024-01-26 19:35:30.743349691
# bidp                                    132.7
# askp                                    134.2
# bid_sz                                     93
# ask_sz                                    103
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           4890.0
# Name: 483811, dtype: object, Closest Put: datetime        2024-01-26 19:36:27.793077072
# bidp                                     46.4
# askp                                     46.8
# bid_sz                                    276
# ask_sz                                    295
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4890.0
# Name: 483820, dtype: object, Overall: 50.005859375
# 2024-01-30
# Date: 2024-01-30, Underlying: 4923.009765625, Closest Call: datetime        2024-01-29 17:04:41.730490412
# bidp                                    198.1
# askp                                    199.7
# bid_sz                                    337
# ask_sz                                    297
# exp_date                  2024-06-21 00:00:00
# action                                      C
# strike_price                           4900.0
# Name: 495450, dtype: object, Closest Put: datetime        2024-01-29 17:00:07.302532844
# bidp                                    133.8
# askp                                    134.8
# bid_sz                                     18
# ask_sz                                     20
# exp_date                  2024-07-19 00:00:00
# action                                      P
# strike_price                           4900.0
# Name: 495226, dtype: object, Overall: 1966.4765625
# 2024-01-31
# Date: 2024-01-31, Underlying: 4887.83984375, Closest Call: datetime        2024-01-30 20:07:19.905506627
# bidp                                     53.8
# askp                                     54.6
# bid_sz                                    390
# ask_sz                                    522
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4925.0
# Name: 529909, dtype: object, Closest Put: datetime        2024-01-30 20:00:15.516928948
# bidp                                     64.5
# askp                                     65.0
# bid_sz                                    327
# ask_sz                                    443
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4925.0
# Name: 529573, dtype: object, Overall: 3596.415625
# 2024-02-01
# Date: 2024-02-01, Underlying: 4876.330078125, Closest Call: datetime        2024-01-31 15:24:54.546432891
# bidp                                     54.6
# askp                                     55.2
# bid_sz                                    290
# ask_sz                                    343
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4885.0
# Name: 537717, dtype: object, Closest Put: datetime        2024-01-31 15:00:00.039430918
# bidp                                     40.0
# askp                                     40.3
# bid_sz                                    154
# ask_sz                                     36
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4885.0
# Name: 536317, dtype: object, Overall: 771.4921875
# 2024-02-02
# Date: 2024-02-02, Underlying: 4923.81005859375, Closest Call: datetime        2024-02-01 17:51:11.429036597
# bidp                                     51.9
# askp                                     52.5
# bid_sz                                     45
# ask_sz                                     45
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4885.0
# Name: 566941, dtype: object, Closest Put: datetime        2024-02-01 17:12:27.432523517
# bidp                                     43.1
# askp                                     43.7
# bid_sz                                    412
# ask_sz                                    510
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4885.0
# Name: 565596, dtype: object, Overall: 3784.805859375
# 2024-02-05
# Date: 2024-02-05, Underlying: 4928.9501953125, Closest Call: datetime        2024-02-02 18:02:34.538283802
# bidp                                     40.5
# askp                                     40.9
# bid_sz                                    167
# ask_sz                                    260
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4965.0
# Name: 592686, dtype: object, Closest Put: datetime        2024-02-02 18:06:16.535917576
# bidp                                     43.6
# askp                                     44.1
# bid_sz                                    186
# ask_sz                                    376
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4965.0
# Name: 592962, dtype: object, Overall: 3519.98046875
# 2024-02-06
# Date: 2024-02-06, Underlying: 4938.64990234375, Closest Call: datetime        2024-02-05 18:00:19.651330271
# bidp                                    487.9
# askp                                    492.1
# bid_sz                                     75
# ask_sz                                     66
# exp_date                  2025-06-20 00:00:00
# action                                      C
# strike_price                           4950.0
# Name: 619511, dtype: object, Closest Put: datetime        2024-02-05 18:00:19.651335087
# bidp                                    256.8
# askp                                    259.1
# bid_sz                                    143
# ask_sz                                    171
# exp_date                  2025-06-20 00:00:00
# action                                      P
# strike_price                           4950.0
# Name: 619512, dtype: object, Overall: 383.80976562499995
# 2024-02-07
# Date: 2024-02-07, Underlying: 4994.39990234375, Closest Call: datetime        2024-02-06 18:10:29.505799662
# bidp                                     83.9
# askp                                     84.8
# bid_sz                                     90
# ask_sz                                     90
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4940.0
# Name: 638432, dtype: object, Closest Put: datetime        2024-02-06 18:14:43.808153645
# bidp                                     61.7
# askp                                     62.2
# bid_sz                                     90
# ask_sz                                     71
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4940.0
# Name: 638530, dtype: object, Overall: 5292.990234375
# 2024-02-08
# Date: 2024-02-08, Underlying: 4992.919921875, Closest Call: datetime        2024-02-07 20:05:58.921045823
# bidp                                     37.3
# askp                                     37.5
# bid_sz                                     65
# ask_sz                                    170
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4995.0
# Name: 668216, dtype: object, Closest Put: datetime        2024-02-07 20:13:15.414206459
# bidp                                     28.7
# askp                                     29.1
# bid_sz                                    215
# ask_sz                                    312
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4995.0
# Name: 668798, dtype: object, Overall: 141.4078125
# 2024-02-09
# Date: 2024-02-09, Underlying: 5010.66015625, Closest Call: datetime        2024-02-08 16:30:21.018715746
# bidp                                     29.2
# askp                                     29.7
# bid_sz                                    637
# ask_sz                                    397
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4995.0
# Name: 686448, dtype: object, Closest Put: datetime        2024-02-08 16:27:46.731058838
# bidp                                     33.0
# askp                                     33.4
# bid_sz                                    282
# ask_sz                                    202
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4995.0
# Name: 686300, dtype: object, Overall: 1502.915625
# 2024-02-12
# Date: 2024-02-12, Underlying: 5026.8701171875, Closest Call: datetime        2024-02-09 19:04:09.338281265
# bidp                                     26.5
# askp                                     26.9
# bid_sz                                    366
# ask_sz                                    249
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           5025.0
# Name: 718160, dtype: object, Closest Put: datetime        2024-02-09 19:01:35.184282246
# bidp                                    117.3
# askp                                    118.0
# bid_sz                                    177
# ask_sz                                     22
# exp_date                  2024-06-21 00:00:00
# action                                      P
# strike_price                           5025.0
# Name: 717964, dtype: object, Overall: 42.111718749999994
# 2024-02-13
# Date: 2024-02-13, Underlying: 4962.18994140625, Closest Call: datetime        2024-02-12 18:08:41.056701588
# bidp                                     87.5
# askp                                     88.1
# bid_sz                                    275
# ask_sz                                    411
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5025.0
# Name: 749261, dtype: object, Closest Put: datetime        2024-02-12 18:00:39.302109438
# bidp                                     75.1
# askp                                     75.6
# bid_sz                                    175
# ask_sz                                    329
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5025.0
# Name: 748987, dtype: object, Overall: 6117.305859375
# 2024-02-14
# Date: 2024-02-14, Underlying: 4989.02978515625, Closest Call: datetime        2024-02-13 18:54:25.483383131
# bidp                                     30.8
# askp                                     31.1
# bid_sz                                     18
# ask_sz                                     96
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           4935.0
# Name: 780946, dtype: object, Closest Put: datetime        2024-02-13 18:01:34.866900368
# bidp                                     13.7
# askp                                     14.0
# bid_sz                                    333
# ask_sz                                    220
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           4935.0
# Name: 778547, dtype: object, Overall: 5357.878515625
# 2024-02-15
# Date: 2024-02-15, Underlying: 5007.490234375, Closest Call: datetime        2024-02-14 20:00:10.746902726
# bidp                                    402.8
# askp                                    407.9
# bid_sz                                    125
# ask_sz                                     90
# exp_date                  2025-02-21 00:00:00
# action                                      C
# strike_price                           5000.0
# Name: 820933, dtype: object, Closest Put: datetime        2024-02-14 20:00:00.413274507
# bidp                                     64.8
# askp                                     65.3
# bid_sz                                      2
# ask_sz                                    135
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5000.0
# Name: 820911, dtype: object, Overall: 275.8234375
# 2024-02-16
# Date: 2024-02-16, Underlying: 5012.9599609375, Closest Call: datetime        2024-02-15 20:00:12.034349448
# bidp                                      9.4
# askp                                      9.9
# bid_sz                                    228
# ask_sz                                    250
# exp_date                  2024-02-16 00:00:00
# action                                      C
# strike_price                           5030.0
# Name: 874749, dtype: object, Closest Put: datetime        2024-02-15 20:00:07.327690916
# bidp                                     10.2
# askp                                     10.7
# bid_sz                                    232
# ask_sz                                    250
# exp_date                  2024-02-16 00:00:00
# action                                      P
# strike_price                           5030.0
# Name: 874741, dtype: object, Overall: 1683.40390625
# 2024-02-20
# Date: 2024-02-20, Underlying: 4971.60986328125, Closest Call: datetime        2024-02-16 20:45:35.839793252
# bidp                                    121.4
# askp                                    122.9
# bid_sz                                    124
# ask_sz                                     96
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5005.0
# Name: 906170, dtype: object, Closest Put: datetime        2024-02-16 20:00:22.335267580
# bidp                                     51.6
# askp                                     52.1
# bid_sz                                     18
# ask_sz                                    360
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5005.0
# Name: 903675, dtype: object, Overall: 3164.013671875
# 2024-02-21
# Date: 2024-02-21, Underlying: 4963.7099609375, Closest Call: datetime        2024-02-20 15:06:50.809599082
# bidp                                    218.9
# askp                                    220.8
# bid_sz                                     94
# ask_sz                                     66
# exp_date                  2024-07-19 00:00:00
# action                                      C
# strike_price                           4980.0
# Name: 912653, dtype: object, Closest Put: datetime        2024-02-20 16:03:59.568912874
# bidp                                     48.5
# askp                                     49.0
# bid_sz                                    473
# ask_sz                                    362
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           4960.0
# Name: 920023, dtype: object, Overall: -269.8
# 2024-02-22
# Date: 2024-02-22, Underlying: 5063.2998046875, Closest Call: datetime        2024-02-21 19:49:05.198360835
# bidp                                     68.4
# askp                                     69.0
# bid_sz                                    400
# ask_sz                                    166
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           4955.0
# Name: 944205, dtype: object, Closest Put: datetime        2024-02-21 19:01:30.409186151
# bidp                                     81.2
# askp                                     82.0
# bid_sz                                     60
# ask_sz                                     60
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           4955.0
# Name: 942749, dtype: object, Overall: 10678.98046875
# 2024-02-23
# Date: 2024-02-23, Underlying: 5102.41015625, Closest Call: datetime        2024-02-22 16:00:11.667504533
# bidp                                     55.6
# askp                                     56.1
# bid_sz                                    225
# ask_sz                                     45
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5070.0
# Name: 958783, dtype: object, Closest Put: datetime        2024-02-22 16:00:11.667499060
# bidp                                     56.3
# askp                                     56.9
# bid_sz                                    337
# ask_sz                                     72
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5070.0
# Name: 958781, dtype: object, Overall: 3128.015625
# 2024-02-26
# Date: 2024-02-26, Underlying: 5089.56005859375, Closest Call: datetime        2024-02-23 17:00:03.230720793
# bidp                                     57.2
# askp                                     57.9
# bid_sz                                    315
# ask_sz                                    505
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5100.0
# Name: 996104, dtype: object, Closest Put: datetime        2024-02-23 17:00:36.651272357
# bidp                                     50.8
# askp                                     51.3
# bid_sz                                    388
# ask_sz                                    278
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5100.0
# Name: 996140, dtype: object, Overall: 934.794140625
# 2024-02-27
# Date: 2024-02-27, Underlying: 5071.68994140625, Closest Call: datetime        2024-02-26 14:49:29.417526412
# bidp                                    180.8
# askp                                    182.2
# bid_sz                                     65
# ask_sz                                     35
# exp_date                  2024-06-21 00:00:00
# action                                      C
# strike_price                           5090.0
# Name: 1009564, dtype: object, Closest Put: datetime        2024-02-26 14:33:25.986703244
# bidp                                     43.3
# askp                                     43.8
# bid_sz                                     45
# ask_sz                                    100
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5090.0
# Name: 1008689, dtype: object, Overall: 1605.005859375
# 2024-02-28
# Date: 2024-02-28, Underlying: 5065.31005859375, Closest Call: datetime        2024-02-27 16:05:39.523217144
# bidp                                     54.7
# askp                                     55.5
# bid_sz                                     45
# ask_sz                                     45
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5065.0
# Name: 1035588, dtype: object, Closest Put: datetime        2024-02-27 16:16:30.427261804
# bidp                                     41.3
# askp                                     41.7
# bid_sz                                    278
# ask_sz                                    310
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5065.0
# Name: 1036159, dtype: object, Overall: -66.194140625
# 2024-02-29
# Date: 2024-02-29, Underlying: 5085.35009765625, Closest Call: datetime        2024-02-28 20:02:16.892484475
# bidp                                     50.8
# askp                                     51.3
# bid_sz                                    262
# ask_sz                                    291
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5070.0
# Name: 1061698, dtype: object, Closest Put: datetime        2024-02-28 20:05:58.180408465
# bidp                                     89.4
# askp                                     90.1
# bid_sz                                    175
# ask_sz                                    254
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5070.0
# Name: 1061892, dtype: object, Overall: 1393.609765625
# 2024-03-01
# Date: 2024-03-01, Underlying: 5111.77978515625, Closest Call: datetime        2024-02-29 15:17:50.192771248
# bidp                                    101.6
# askp                                    102.6
# bid_sz                                     53
# ask_sz                                     62
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5080.0
# Name: 1069044, dtype: object, Closest Put: datetime        2024-02-29 15:10:53.918038292
# bidp                                     38.2
# askp                                     38.7
# bid_sz                                    556
# ask_sz                                     75
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5080.0
# Name: 1068519, dtype: object, Overall: 3036.678515625
# 2024-03-04
# Date: 2024-03-04, Underlying: 5133.14013671875, Closest Call: datetime        2024-03-01 17:01:24.577213868
# bidp                                     39.8
# askp                                     40.2
# bid_sz                                    342
# ask_sz                                    141
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5130.0
# Name: 1092120, dtype: object, Closest Put: datetime        2024-03-01 17:01:24.577208375
# bidp                                     44.1
# askp                                     44.7
# bid_sz                                    578
# ask_sz                                    383
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5130.0
# Name: 1092119, dtype: object, Overall: 229.113671875
# 2024-03-05
# Date: 2024-03-05, Underlying: 5091.3701171875, Closest Call: datetime        2024-03-04 16:00:35.886317383
# bidp                                     40.9
# askp                                     41.3
# bid_sz                                    378
# ask_sz                                    200
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5140.0
# Name: 1113145, dtype: object, Closest Put: datetime        2024-03-04 16:00:35.886312322
# bidp                                     38.6
# askp                                     39.1
# bid_sz                                    189
# ask_sz                                    610
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5140.0
# Name: 1113144, dtype: object, Overall: 4782.58828125
# 2024-03-06
# Date: 2024-03-06, Underlying: 5101.5498046875, Closest Call: datetime        2024-03-05 17:01:53.107358997
# bidp                                     44.2
# askp                                     44.7
# bid_sz                                    354
# ask_sz                                    186
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5085.0
# Name: 1140556, dtype: object, Closest Put: datetime        2024-03-05 17:01:13.420102529
# bidp                                    111.9
# askp                                    112.6
# bid_sz                                     49
# ask_sz                                     91
# exp_date                  2024-06-21 00:00:00
# action                                      P
# strike_price                           5085.0
# Name: 1140542, dtype: object, Overall: 1497.68046875
# 2024-03-07
# Date: 2024-03-07, Underlying: 5148.75, Closest Call: datetime        2024-03-06 16:01:29.672382940
# bidp                                     37.4
# askp                                     37.9
# bid_sz                                    374
# ask_sz                                    450
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5125.0
# Name: 1164206, dtype: object, Closest Put: datetime        2024-03-06 16:02:16.522809514
# bidp                                    232.1
# askp                                    233.6
# bid_sz                                    112
# ask_sz                                     76
# exp_date                  2025-03-21 00:00:00
# action                                      P
# strike_price                           5125.0
# Name: 1164252, dtype: object, Overall: 2103.5
# 2024-03-08
# Date: 2024-03-08, Underlying: 5186.490234375, Closest Call: datetime        2024-03-07 18:22:37.852236987
# bidp                                     37.4
# askp                                     37.8
# bid_sz                                    182
# ask_sz                                    274
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5160.0
# Name: 1191568, dtype: object, Closest Put: datetime        2024-03-07 18:06:35.954961984
# bidp                                     40.5
# askp                                     40.9
# bid_sz                                    216
# ask_sz                                    368
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5160.0
# Name: 1191012, dtype: object, Overall: 2570.3234375
# 2024-03-11
# Date: 2024-03-11, Underlying: 5096.0498046875, Closest Call: datetime        2024-03-08 17:42:10.491492303
# bidp                                     51.7
# askp                                     52.6
# bid_sz                                    237
# ask_sz                                     88
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5130.0
# Name: 1229977, dtype: object, Closest Put: datetime        2024-03-08 17:22:47.864101733
# bidp                                     28.6
# askp                                     29.1
# bid_sz                                    108
# ask_sz                                    307
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5130.0
# Name: 1229204, dtype: object, Overall: 3313.31953125
# 2024-03-12
# Date: 2024-03-12, Underlying: 5157.0400390625, Closest Call: datetime        2024-03-11 18:05:00.916882996
# bidp                                     35.8
# askp                                     36.4
# bid_sz                                     34
# ask_sz                                     61
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5115.0
# Name: 1260474, dtype: object, Closest Put: datetime        2024-03-11 18:04:12.142241093
# bidp                                     29.5
# askp                                     30.0
# bid_sz                                    161
# ask_sz                                    235
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5115.0
# Name: 1260441, dtype: object, Overall: 4137.60390625
# 2024-03-13
# Date: 2024-03-13, Underlying: 5170.39990234375, Closest Call: datetime        2024-03-12 19:09:01.415869560
# bidp                                     23.3
# askp                                     23.7
# bid_sz                                     67
# ask_sz                                    105
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5175.0
# Name: 1292554, dtype: object, Closest Put: datetime        2024-03-12 19:02:35.993665908
# bidp                                     22.2
# askp                                     22.7
# bid_sz                                     90
# ask_sz                                     32
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5175.0
# Name: 1292110, dtype: object, Overall: 413.609765625
# 2024-03-14
# Date: 2024-03-14, Underlying: 5155.52001953125, Closest Call: datetime        2024-03-13 13:30:05.542491003
# bidp                                     22.8
# askp                                     23.4
# bid_sz                                     24
# ask_sz                                     40
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5170.0
# Name: 1298298, dtype: object, Closest Put: datetime        2024-03-13 13:36:21.770534046
# bidp                                     85.9
# askp                                     86.5
# bid_sz                                     79
# ask_sz                                    121
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5170.0
# Name: 1298794, dtype: object, Overall: 1338.098046875
# 2024-03-15
# Date: 2024-03-15, Underlying: 5124.7998046875, Closest Call: datetime        2024-03-14 13:31:33.328410956
# bidp                                     26.0
# askp                                     26.5
# bid_sz                                    115
# ask_sz                                     19
# exp_date                  2024-03-15 00:00:00
# action                                      C
# strike_price                           5155.0
# Name: 1325648, dtype: object, Closest Put: datetime        2024-03-14 13:32:33.434088986
# bidp                                      7.4
# askp                                      7.7
# bid_sz                                    277
# ask_sz                                     96
# exp_date                  2024-03-15 00:00:00
# action                                      P
# strike_price                           5155.0
# Name: 1325879, dtype: object, Overall: 2985.81953125
# 2024-03-18
# Date: 2024-03-18, Underlying: 5172.25, Closest Call: datetime        2024-03-15 13:44:53.085106067
# bidp                                    169.7
# askp                                    171.4
# bid_sz                                     28
# ask_sz                                     24
# exp_date                  2024-06-21 00:00:00
# action                                      C
# strike_price                           5125.0
# Name: 1391724, dtype: object, Closest Put: datetime        2024-03-15 13:32:21.428950332
# bidp                                     86.4
# askp                                     87.1
# bid_sz                                     31
# ask_sz                                    107
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5125.0
# Name: 1391034, dtype: object, Overall: 4466.5
# 2024-03-19
# Date: 2024-03-19, Underlying: 5134.990234375, Closest Call: datetime        2024-03-18 19:00:01.084022558
# bidp                                     91.9
# askp                                     92.7
# bid_sz                                    252
# ask_sz                                    285
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5150.0
# Name: 1429943, dtype: object, Closest Put: datetime        2024-03-18 19:05:58.750683886
# bidp                                     59.8
# askp                                     60.3
# bid_sz                                    220
# ask_sz                                    365
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5150.0
# Name: 1430091, dtype: object, Overall: 1347.9765625
# 2024-03-20
# Date: 2024-03-20, Underlying: 5183.85009765625, Closest Call: datetime        2024-03-19 13:47:04.353291456
# bidp                                     86.3
# askp                                     86.6
# bid_sz                                    271
# ask_sz                                     29
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5135.0
# Name: 1433870, dtype: object, Closest Put: datetime        2024-03-19 13:42:14.301089673
# bidp                                    109.1
# askp                                    109.9
# bid_sz                                    166
# ask_sz                                     49
# exp_date                  2024-06-21 00:00:00
# action                                      P
# strike_price                           5135.0
# Name: 1433680, dtype: object, Overall: 4688.509765625
# 2024-03-21
# Date: 2024-03-21, Underlying: 5257.5498046875, Closest Call: datetime        2024-03-20 16:11:48.713252900
# bidp                                    442.7
# askp                                    447.1
# bid_sz                                     24
# ask_sz                                     69
# exp_date                  2025-03-21 00:00:00
# action                                      C
# strike_price                           5175.0
# Name: 1456698, dtype: object, Closest Put: datetime        2024-03-20 16:09:46.562745337
# bidp                                     82.0
# askp                                     82.7
# bid_sz                                    124
# ask_sz                                    162
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5175.0
# Name: 1456647, dtype: object, Overall: 7725.18046875
# 2024-03-22
# Date: 2024-03-22, Underlying: 5238.27978515625, Closest Call: datetime        2024-03-21 15:08:07.081449849
# bidp                                     70.2
# askp                                     70.8
# bid_sz                                     90
# ask_sz                                    135
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5260.0
# Name: 1484380, dtype: object, Closest Put: datetime        2024-03-21 15:15:02.861147039
# bidp                                     56.6
# askp                                     57.1
# bid_sz                                    334
# ask_sz                                    154
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5260.0
# Name: 1484758, dtype: object, Overall: 2044.121484375
# 2024-03-25
# Date: 2024-03-25, Underlying: 5224.68017578125, Closest Call: datetime        2024-03-22 17:20:00.314615957
# bidp                                     68.4
# askp                                     69.0
# bid_sz                                    289
# ask_sz                                    210
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5245.0
# Name: 1511489, dtype: object, Closest Put: datetime        2024-03-22 15:02:45.989609214
# bidp                                     52.8
# askp                                     53.3
# bid_sz                                    277
# ask_sz                                    255
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5235.0
# Name: 1507109, dtype: object, Overall: 909.682421875
# 2024-03-26
# Date: 2024-03-26, Underlying: 5230.47021484375, Closest Call: datetime        2024-03-25 15:01:11.519039357
# bidp                                    191.3
# askp                                    192.5
# bid_sz                                     64
# ask_sz                                     74
# exp_date                  2024-07-19 00:00:00
# action                                      C
# strike_price                           5225.0
# Name: 1522830, dtype: object, Closest Put: datetime        2024-03-25 15:14:17.801412937
# bidp                                    195.5
# askp                                    196.4
# bid_sz                                     52
# ask_sz                                    253
# exp_date                  2024-12-20 00:00:00
# action                                      P
# strike_price                           5225.0
# Name: 1523315, dtype: object, Overall: 158.12148437500002
# 2024-03-27
# Date: 2024-03-27, Underlying: 5217.9501953125, Closest Call: datetime        2024-03-26 13:31:33.094129850
# bidp                                     66.6
# askp                                     67.5
# bid_sz                                     45
# ask_sz                                      1
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5230.0
# Name: 1534105, dtype: object, Closest Put: datetime        2024-03-26 13:45:59.740636210
# bidp                                     75.4
# askp                                     75.9
# bid_sz                                    175
# ask_sz                                    180
# exp_date                  2024-05-17 00:00:00
# action                                      P
# strike_price                           5230.0
# Name: 1534932, dtype: object, Overall: 1061.58046875
# 2024-03-28
# Date: 2024-03-28, Underlying: 5250.33984375, Closest Call: datetime        2024-03-27 15:06:04.051555127
# bidp                                     62.1
# askp                                     62.7
# bid_sz                                    271
# ask_sz                                    210
# exp_date                  2024-04-19 00:00:00
# action                                      C
# strike_price                           5220.0
# Name: 1554722, dtype: object, Closest Put: datetime        2024-03-27 15:06:36.663306542
# bidp                                     48.7
# askp                                     49.1
# bid_sz                                    262
# ask_sz                                    173
# exp_date                  2024-04-19 00:00:00
# action                                      P
# strike_price                           5220.0
# Name: 1554740, dtype: object, Overall: 2922.184375
